# %%
import cv2
import matplotlib.pyplot as plt

# %%
#read the image

img=cv2.imread('python.png')
newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()

plt.imshow(newimg)
plt.show()
